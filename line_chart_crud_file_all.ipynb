# %%
import pandas as pd

# %%
df_athlete = pd.read_csv("../Project2/data/athlete_events.csv")

# %%
df_athlete[['Medal']] = df_athlete[['Medal']].fillna(value=0)
df_athlete_medal = df_athlete[df_athlete.Medal != 0]
df_athlete_medal.head()
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 37  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 38  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#     NOC        Games  Year  Season       City       Sport  \
# 3   DEN  1900 Summer  1900  Summer      Paris  Tug-Of-War
# 37  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 38  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 40  FIN  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 41  FIN  1948 Summer  1948  Summer     London  Gymnastics
#
#                                      Event   Medal
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 37  Swimming Men's 200 metres Breaststroke  Bronze
# ...

# %%
df_athlete_medal.dtypes
# Out:
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
#df_athlete_medal_grpby_male_summer = df_athlete_medal[(df_athlete_medal.Season == 'Summer')]
#df_athlete_medal_grpby_male_summer = df_athlete_medal_grpby_male_summer[(df_athlete_medal_grpby_male_summer.Sex == 'M')]
df_athlete_medal_grpby = pd.DataFrame(df_athlete_medal.groupby(['Year', 'Sex', 'Season'])['Medal'].count())
df_athlete_medal_grpby.reset_index(inplace = True)
df_athlete_medal_grpby= df_athlete_medal_grpby.astype(str)
df_athlete_medal_grpby.head()
# Out:
#    Year Sex  Season Medal
# 0  1896   M  Summer   143
# 1  1900   F  Summer    13
# 2  1900   M  Summer   591
# 3  1904   F  Summer    10
# 4  1904   M  Summer   476

# %%
#df_athlete_medal_grpby.to_csv('../Project2/data/line_chart_data.csv')

# %%
# read manual modified file
df_athlete = pd.read_csv("../Project2/data/line_chart_data.csv")

# %%
df_athlete = df_athlete.astype(str)
df_athlete.head()
# Out:
#    Year Sex  Season Medal     Season_Sex
# 0  1896   F  Summer     0  Summer_Female
# 1  1900   F  Summer    13  Summer_Female
# 2  1904   F  Summer    10  Summer_Female
# 3  1906   F  Summer     6  Summer_Female
# 4  1908   F  Summer    16  Summer_Female

# %%
df_athlete.dtypes
# Out:
# Year          object
# Sex           object
# Season        object
# Medal         object
# Season_Sex    object
# dtype: object

# %%
linechartdict = {}
linechartlist = []
for i in range(len(df_athlete)):
    linechartdict["year"] = df_athlete.iloc[i,0]
    linechartdict["sex"] = df_athlete.iloc[i,1]
    linechartdict["season"] = df_athlete.iloc[i,2]
    linechartdict["medal"] = df_athlete.iloc[i,3]
    linechartdict["season_sex"] = df_athlete.iloc[i,4]

    linechartlist.append(linechartdict)    
    linechartdict = {}

# %%
linechartlist
# Out:
# [{'year': '1896',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '0',
#   'season_sex': 'Summer_Female'},
#  {'year': '1900',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '13',
#   'season_sex': 'Summer_Female'},
#  {'year': '1904',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '10',
#   'season_sex': 'Summer_Female'},
#  {'year': '1906',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '6',
#   'season_sex': 'Summer_Female'},
#  {'year': '1908',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '16',
#   'season_sex': 'Summer_Female'},
#  {'year': '1912',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '30',
#   'season_sex': 'Summer_Female'},
#  {'year': '1920',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '44',
#   'season_sex': 'Summer_Female'},
#  {'year': '1924',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '46',
#   'season_sex': 'Summer_Female'},
#  {'year': '1928',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '97',
# ...

# %%
#df_athlete = pd.read_csv("../data/line_chart_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-61e666800ad1> in <module>
# ----> 1 df_athlete = pd.read_csv("../data/line_chart_data.csv")
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
# ...
