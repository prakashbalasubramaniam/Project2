# %%
import pandas as pd

# %%
df_athlete = pd.read_csv("../Project2/data/athlete_noc_grpby_country_year_medal.csv")
df_athlete.head()
# Out:
#    noc      country  year      lat      lng  medal_count
# 0  AFG  Afghanistan  2008  34.0230  65.5267            1
# 1  AFG  Afghanistan  2012  34.0230  65.5267            1
# 2  AHO      Curacao  1988  12.1660 -69.0000            1
# 3  ALG      Algeria  1984  28.6045   2.6400            2
# 4  ALG      Algeria  1992  28.6045   2.6400            2

# %%
df_athlete_medal = df_athlete
df_athlete_medal.dtypes
# Out:
# noc             object
# country         object
# year             int64
# lat            float64
# lng            float64
# medal_count      int64
# dtype: object

# %%
df_athlete_medal = df_athlete_medal.astype(str)
df_athlete_medal.head()
# Out:
#    noc      country  year                 lat      lng medal_count
# 0  AFG  Afghanistan  2008              34.023  65.5267           1
# 1  AFG  Afghanistan  2012              34.023  65.5267           1
# 2  AHO      Curacao  1988  12.165999999999999    -69.0           1
# 3  ALG      Algeria  1984             28.6045     2.64           2
# 4  ALG      Algeria  1992             28.6045     2.64           2

# %%
df_athlete_medal.dtypes
# Out:
# noc            object
# country        object
# year           object
# lat            object
# lng            object
# medal_count    object
# dtype: object

# %%
mapchartdict = {}
mapchartlist = []
for i in range(len(df_athlete)):
    linechartdict["year"] = df_athlete.iloc[i,0]
    linechartdict["sex"] = df_athlete.iloc[i,1]
    linechartdict["season"] = df_athlete.iloc[i,2]
    linechartdict["medal"] = df_athlete.iloc[i,3]
    linechartdict["season_sex"] = df_athlete.iloc[i,4]

    linechartlist.append(linechartdict)    
    linechartdict = {}

# %%
linechartlist
# Out:
# [{'year': '1896',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '0',
#   'season_sex': 'Summer_Female'},
#  {'year': '1900',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '13',
#   'season_sex': 'Summer_Female'},
#  {'year': '1904',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '10',
#   'season_sex': 'Summer_Female'},
#  {'year': '1906',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '6',
#   'season_sex': 'Summer_Female'},
#  {'year': '1908',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '16',
#   'season_sex': 'Summer_Female'},
#  {'year': '1912',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '30',
#   'season_sex': 'Summer_Female'},
#  {'year': '1920',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '44',
#   'season_sex': 'Summer_Female'},
#  {'year': '1924',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '46',
#   'season_sex': 'Summer_Female'},
#  {'year': '1928',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '97',
#   'season_sex': 'Summer_Female'},
#  {'year': '1932',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '62',
#   'season_sex': 'Summer_Female'},
#  {'year': '1936',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '88',
#   'season_sex': 'Summer_Female'},
#  {'year': '1948',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '101',
#   'season_sex': 'Summer_Female'},
#  {'year': '1952',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '140',
#   'season_sex': 'Summer_Female'},
#  {'year': '1956',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '144',
#   'season_sex': 'Summer_Female'},
#  {'year': '1960',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '156',
#   'season_sex': 'Summer_Female'},
#  {'year': '1964',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '200',
#   'season_sex': 'Summer_Female'},
#  {'year': '1968',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '215',
#   'season_sex': 'Summer_Female'},
#  {'year': '1972',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '250',
#   'season_sex': 'Summer_Female'},
#  {'year': '1976',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '389',
#   'season_sex': 'Summer_Female'},
#  {'year': '1980',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '434',
#   'season_sex': 'Summer_Female'},
#  {'year': '1984',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '494',
#   'season_sex': 'Summer_Female'},
#  {'year': '1988',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '554',
#   'season_sex': 'Summer_Female'},
#  {'year': '1992',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '592',
#   'season_sex': 'Summer_Female'},
#  {'year': '1994',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '0',
#   'season_sex': 'Summer_Female'},
#  {'year': '1996',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '764',
#   'season_sex': 'Summer_Female'},
#  {'year': '1998',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '0',
#   'season_sex': 'Summer_Female'},
#  {'year': '2000',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '880',
#   'season_sex': 'Summer_Female'},
#  {'year': '2002',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '0',
#   'season_sex': 'Summer_Female'},
#  {'year': '2004',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '898',
#   'season_sex': 'Summer_Female'},
#  {'year': '2006',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '0',
#   'season_sex': 'Summer_Female'},
#  {'year': '2008',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '932',
#   'season_sex': 'Summer_Female'},
#  {'year': '2010',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '0',
#   'season_sex': 'Summer_Female'},
#  {'year': '2012',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '918',
#   'season_sex': 'Summer_Female'},
#  {'year': '2014',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '0',
#   'season_sex': 'Summer_Female'},
#  {'year': '2016',
#   'sex': 'F',
#   'season': 'Summer',
#   'medal': '969',
#   'season_sex': 'Summer_Female'},
#  {'year': '1896',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Female'},
#  {'year': '1900',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Female'},
#  {'year': '1904',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Female'},
#  {'year': '1906',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Female'},
#  {'year': '1908',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Female'},
#  {'year': '1912',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Female'},
#  {'year': '1920',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Female'},
#  {'year': '1924',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '6',
#   'season_sex': 'Winter_Female'},
#  {'year': '1928',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '6',
#   'season_sex': 'Winter_Female'},
#  {'year': '1932',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '6',
#   'season_sex': 'Winter_Female'},
#  {'year': '1936',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '9',
#   'season_sex': 'Winter_Female'},
#  {'year': '1948',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '15',
#   'season_sex': 'Winter_Female'},
#  {'year': '1952',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '18',
#   'season_sex': 'Winter_Female'},
#  {'year': '1956',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '27',
#   'season_sex': 'Winter_Female'},
#  {'year': '1960',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '39',
#   'season_sex': 'Winter_Female'},
#  {'year': '1964',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '46',
#   'season_sex': 'Winter_Female'},
#  {'year': '1968',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '46',
#   'season_sex': 'Winter_Female'},
#  {'year': '1972',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '45',
#   'season_sex': 'Winter_Female'},
#  {'year': '1976',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '51',
#   'season_sex': 'Winter_Female'},
#  {'year': '1980',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '51',
#   'season_sex': 'Winter_Female'},
#  {'year': '1984',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '54',
#   'season_sex': 'Winter_Female'},
#  {'year': '1988',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '63',
#   'season_sex': 'Winter_Female'},
#  {'year': '1992',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '99',
#   'season_sex': 'Winter_Female'},
#  {'year': '1994',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '108',
#   'season_sex': 'Winter_Female'},
#  {'year': '1996',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Female'},
#  {'year': '1998',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '189',
#   'season_sex': 'Winter_Female'},
#  {'year': '2000',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Female'},
#  {'year': '2002',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '208',
#   'season_sex': 'Winter_Female'},
#  {'year': '2004',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Female'},
#  {'year': '2006',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '231',
#   'season_sex': 'Winter_Female'},
#  {'year': '2008',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Female'},
#  {'year': '2010',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '229',
#   'season_sex': 'Winter_Female'},
#  {'year': '2012',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Female'},
#  {'year': '2014',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '265',
#   'season_sex': 'Winter_Female'},
#  {'year': '2016',
#   'sex': 'F',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Female'},
#  {'year': '1896',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '143',
#   'season_sex': 'Summer_Male'},
#  {'year': '1900',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '591',
#   'season_sex': 'Summer_Male'},
#  {'year': '1904',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '476',
#   'season_sex': 'Summer_Male'},
#  {'year': '1906',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '452',
#   'season_sex': 'Summer_Male'},
#  {'year': '1908',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '815',
#   'season_sex': 'Summer_Male'},
#  {'year': '1912',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '911',
#   'season_sex': 'Summer_Male'},
#  {'year': '1920',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '1264',
#   'season_sex': 'Summer_Male'},
#  {'year': '1924',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '786',
#   'season_sex': 'Summer_Male'},
#  {'year': '1928',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '637',
#   'season_sex': 'Summer_Male'},
#  {'year': '1932',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '585',
#   'season_sex': 'Summer_Male'},
#  {'year': '1936',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '829',
#   'season_sex': 'Summer_Male'},
#  {'year': '1948',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '751',
#   'season_sex': 'Summer_Male'},
#  {'year': '1952',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '757',
#   'season_sex': 'Summer_Male'},
#  {'year': '1956',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '749',
#   'season_sex': 'Summer_Male'},
#  {'year': '1960',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '755',
#   'season_sex': 'Summer_Male'},
#  {'year': '1964',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '829',
#   'season_sex': 'Summer_Male'},
#  {'year': '1968',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '842',
#   'season_sex': 'Summer_Male'},
#  {'year': '1972',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '965',
#   'season_sex': 'Summer_Male'},
#  {'year': '1976',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '931',
#   'season_sex': 'Summer_Male'},
#  {'year': '1980',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '950',
#   'season_sex': 'Summer_Male'},
#  {'year': '1984',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '982',
#   'season_sex': 'Summer_Male'},
#  {'year': '1988',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '1028',
#   'season_sex': 'Summer_Male'},
#  {'year': '1992',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '1120',
#   'season_sex': 'Summer_Male'},
#  {'year': '1994',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '0',
#   'season_sex': 'Summer_Male'},
#  {'year': '1996',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '1078',
#   'season_sex': 'Summer_Male'},
#  {'year': '1998',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '0',
#   'season_sex': 'Summer_Male'},
#  {'year': '2000',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '1124',
#   'season_sex': 'Summer_Male'},
#  {'year': '2002',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '0',
#   'season_sex': 'Summer_Male'},
#  {'year': '2004',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '1103',
#   'season_sex': 'Summer_Male'},
#  {'year': '2006',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '0',
#   'season_sex': 'Summer_Male'},
#  {'year': '2008',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '1116',
#   'season_sex': 'Summer_Male'},
#  {'year': '2010',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '0',
#   'season_sex': 'Summer_Male'},
#  {'year': '2012',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '1023',
#   'season_sex': 'Summer_Male'},
#  {'year': '2014',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '0',
#   'season_sex': 'Summer_Male'},
#  {'year': '2016',
#   'sex': 'M',
#   'season': 'Summer',
#   'medal': '1054',
#   'season_sex': 'Summer_Male'},
#  {'year': '1896',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Male'},
#  {'year': '1900',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Male'},
#  {'year': '1904',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Male'},
#  {'year': '1906',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Male'},
#  {'year': '1908',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Male'},
#  {'year': '1912',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Male'},
#  {'year': '1920',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Male'},
#  {'year': '1924',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '124',
#   'season_sex': 'Winter_Male'},
#  {'year': '1928',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '83',
#   'season_sex': 'Winter_Male'},
#  {'year': '1932',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '86',
#   'season_sex': 'Winter_Male'},
#  {'year': '1936',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '99',
#   'season_sex': 'Winter_Male'},
#  {'year': '1948',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '120',
#   'season_sex': 'Winter_Male'},
#  {'year': '1952',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '118',
#   'season_sex': 'Winter_Male'},
#  {'year': '1956',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '123',
#   'season_sex': 'Winter_Male'},
#  {'year': '1960',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '108',
#   'season_sex': 'Winter_Male'},
#  {'year': '1964',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '140',
#   'season_sex': 'Winter_Male'},
#  {'year': '1968',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '153',
#   'season_sex': 'Winter_Male'},
#  {'year': '1972',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '154',
#   'season_sex': 'Winter_Male'},
#  {'year': '1976',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '160',
#   'season_sex': 'Winter_Male'},
#  {'year': '1980',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '167',
#   'season_sex': 'Winter_Male'},
#  {'year': '1984',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '168',
#   'season_sex': 'Winter_Male'},
#  {'year': '1988',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '200',
#   'season_sex': 'Winter_Male'},
#  {'year': '1992',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '219',
#   'season_sex': 'Winter_Male'},
#  {'year': '1994',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '223',
#   'season_sex': 'Winter_Male'},
#  {'year': '1996',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Male'},
#  {'year': '1998',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '251',
#   'season_sex': 'Winter_Male'},
#  {'year': '2000',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Male'},
#  {'year': '2002',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '270',
#   'season_sex': 'Winter_Male'},
#  {'year': '2004',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Male'},
#  {'year': '2006',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '295',
#   'season_sex': 'Winter_Male'},
#  {'year': '2008',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Male'},
#  {'year': '2010',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '291',
#   'season_sex': 'Winter_Male'},
#  {'year': '2012',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Male'},
#  {'year': '2014',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '332',
#   'season_sex': 'Winter_Male'},
#  {'year': '2016',
#   'sex': 'M',
#   'season': 'Winter',
#   'medal': '0',
#   'season_sex': 'Winter_Male'}]

# %%
#df_athlete = pd.read_csv("../data/line_chart_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-61e666800ad1> in <module>
# ----> 1 df_athlete = pd.read_csv("../data/line_chart_data.csv")
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'../data/line_chart_data.csv' does not exist: b'../data/line_chart_data.csv'
