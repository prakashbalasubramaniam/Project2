# %%
import pandas as pd

# %%
df= pd.read_csv("../Project2/data/athlete_events.csv")

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df[['Medal']] = df[['Medal']].fillna(value=0)
df_athlete_medal = df[df.Medal != 0]
df_athlete_medal.head()
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 37  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 38  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#     NOC        Games  Year  Season       City       Sport  \
# 3   DEN  1900 Summer  1900  Summer      Paris  Tug-Of-War
# 37  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 38  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 40  FIN  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 41  FIN  1948 Summer  1948  Summer     London  Gymnastics
#
#                                      Event   Medal
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 37  Swimming Men's 200 metres Breaststroke  Bronze
# ...

# %%
df3=df_athlete_medal.groupby(['Team','Name']).count()

# %%
df3.sort_values(by = 'ID', ascending=False)
# Out:
#                                                                 ID  Sex  Age  \
# Team           Name
# United States  Michael Fred Phelps, II                          28   28   28
# Soviet Union   Larysa Semenivna Latynina (Diriy-)               18   18   18
#                Nikolay Yefimovich Andrianov                     15   15   15
# Japan          Takashi Ono                                      13   13   13
# Soviet Union   Borys Anfiyanovych Shakhlin                      13   13   13
# Italy          Edoardo Mangiarotti                              13   13   13
# Norway         Ole Einar Bjrndalen                              13   13   13
# Russia         Aleksey Yuryevich Nemov                          12   12   12
# United States  Ryan Steven Lochte                               12   12   12
# Finland        Paavo Johannes Nurmi                             12   12   12
# United States  Natalie Anne Coughlin (-Hall)                    12   12   12
# ...

# %%
df3.reset_index(inplace=True)

# %%
df3[['Name','ID','Team']]
# Out:
#                                                     Name  ID  \
# 0           Jos Eustaquio Luis Francisco Escandn y Barrn   1
# 1      Jos Manuel Mara del Corazn de Jess Escandn y B...   1
# 2      Jos Pablo Eustaquio Manuel Francisco Escandn y...   1
# 3                                  William Hayden Wright   1
# 4                                        Rohullah Nikpai   2
# 5                             Abderrahmane Hammad Zaheer   1
# 6                                          Ali Sadi-Sief   1
# 7                                         Amar Benikhlef   1
# 8                                 Assa Djabir Sad-Guerni   1
# 9                                      Hassiba Boulmerka   1
# 10                                        Hocine Soltani   2
# 11                                       Mohamed Allalou   1
# 12                                        Mohamed Bahari   1
# 13                                         Mohamed Zaoui   1
# ...

# %%
df3.sort_values('ID', ascending=False)
# Out:
#                  Team                                             Name  ID  \
# 26608   United States                          Michael Fred Phelps, II  28
# 20398    Soviet Union               Larysa Semenivna Latynina (Diriy-)  18
# 20653    Soviet Union                     Nikolay Yefimovich Andrianov  15
# 14479           Japan                                      Takashi Ono  13
# 20130    Soviet Union                      Borys Anfiyanovych Shakhlin  13
# 13086           Italy                              Edoardo Mangiarotti  13
# 16813          Norway                              Ole Einar Bjrndalen  13
# 18237          Russia                          Aleksey Yuryevich Nemov  12
# 27146   United States                               Ryan Steven Lochte  12
# 7343          Finland                             Paavo Johannes Nurmi  12
# 26699   United States                    Natalie Anne Coughlin (-Hall)  12
# ...

# %%
bar_dict=df3.to_dict(orient="records")

# %%
from pymongo import MongoClient

# %%
mongo_client = MongoClient("mongodb+srv://admin:Password123@cluster0-on1i6.mongodb.net/test?retryWrites=true&w=majority")

# %%
db = mongo_client.olympic_info_db
collection = db.bar_dict

# %%
collection.find()

# %%
collection.insert_many(bar_dict)

# %%
list(collection.find())
# Out:
# [{'_id': ObjectId('5d8fc19675150990cafe28e6'),
#   'Team': 'A North American Team',
#   'Name': 'Jos Eustaquio Luis Francisco Escandn y Barrn',
#   'ID': 1,
#   'Sex': 1,
#   'Age': 1,
#   'Height': 0,
#   'Weight': 0,
#   'NOC': 1,
#   'Games': 1,
#   'Year': 1,
#   'Season': 1,
#   'City': 1,
#   'Sport': 1,
#   'Event': 1,
#   'Medal': 1},
#  {'_id': ObjectId('5d8fc19675150990cafe28e7'),
#   'Team': 'A North American Team',
#   'Name': 'Jos Manuel Mara del Corazn de Jess Escandn y Barrn',
#   'ID': 1,
#   'Sex': 1,
#   'Age': 1,
#   'Height': 0,
#   'Weight': 0,
#   'NOC': 1,
#   'Games': 1,
#   'Year': 1,
#   'Season': 1,
#   'City': 1,
#   'Sport': 1,
#   'Event': 1,
#   'Medal': 1},
#  {'_id': ObjectId('5d8fc19675150990cafe28e8'),
#   'Team': 'A North American Team',
#   'Name': 'Jos Pablo Eustaquio Manuel Francisco Escandn y Barrn',
#   'ID': 1,
#   'Sex': 1,
#   'Age': 1,
#   'Height': 0,
#   'Weight': 0,
#   'NOC': 1,
#   'Games': 1,
#   'Year': 1,
#   'Season': 1,
# ...
